# %%
import analyzer
from analyzer import SpectrumAnalyzer

# %config InlineBackend.figure_format='retina'

# %load_ext autoreload
# %autoreload 2

# %%
# Analysis of Monroe Guided Meditation - Collective Guidance (SAM) from
# https://archive.org/details/tmi-meditation-collective-guidance-sam
path = "samples/Collective Guidance (SAM).mp3"
a = SpectrumAnalyzer(path)

# %%
a.plot_spectrogram("10:00", "29:00")

# %%
a.fft("10:00", "30:00")

# %%
a.plot_spectrum(20, 800)

# %%
a.plot_spectrum(130, 260, min_peak_dist=3)

# %%
a.plot_spectrum(450, 700, min_peak_dist=40)
